# %% [markdown]
# # Feature Engineering Pipeline
#
# Prepares features for model training, maps categorical weather to integers, and standardizes feature matrices.

# %%
import sys
import os
sys.path.append('../src')

import pandas as pd
from feature_engineering import extract_features

df = pd.read_csv('../data/processed/train_dataset.csv')
X, y = extract_features(df)
X.head()
