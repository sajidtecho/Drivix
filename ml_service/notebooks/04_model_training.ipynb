# %% [markdown]
# # Model Training and Validation
#
# Trains Random Forest/XGBoost Regressors and tracks metrics.

# %%
import sys
import os
sys.path.append('../src')

from train import train_model
from evaluate import evaluate_model

# Run the full training pipeline
train_model(train_path='../data/processed/train_dataset.csv', model_dir='../models')

# Evaluate on test splits
evaluate_model(model_path='../models/drivix_price_model.pkl', test_path='../data/processed/test_dataset.csv')
