# %% [markdown]
# # Drivix Data Audit Notebook
#
# This notebook performs the initial data audit for the Drivix dynamic pricing model.

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('../data/raw/drivix_pricing_dataset.csv')
df.head()

# %%
df.info()
df.describe()
